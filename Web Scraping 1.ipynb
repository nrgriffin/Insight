# %%
import requests
from bs4 import BeautifulSoup

# %%
result = requests.get("https://www.mountainproject.com/route/105722593/white-rastafarian")
print(result.status_code)
# Out:
# 200

# %%
print(result.headers)
# Out:
# {'Date': 'Mon, 16 Sep 2019 20:03:39 GMT', 'Server': 'Apache', 'Set-Cookie': 'photoIds=%5B%5D; expires=Tue, 17-Sep-2019 20:03:39 GMT; Max-Age=86400; path=/; domain=.mountainproject.com, photosTitle=Nearby+Photos; expires=Tue, 17-Sep-2019 20:03:39 GMT; Max-Age=86400; path=/; domain=.mountainproject.com, pageCount=1; expires=Thu, 13-Sep-2029 20:03:39 GMT; Max-Age=315360000; path=/; domain=.mountainproject.com, XSRF-TOKEN=eyJpdiI6Im10RlZJT2ZPNEpteG9wZ3NLVWRaRGc9PSIsInZhbHVlIjoiNnpSSmdiSXRRVHlvSVE5ZmJ5TWZPMEhXY0tEVUZRUElFbVFMRTF2YThodmRlQmtzSkk4amQxZlBIZHdTbDlueCIsIm1hYyI6ImNiNGRiYjc3Yzg5MTc0ZTQyYTNjZTcyODhiZDNkNWZhMGViMTk3OTRmMmJiNDcyODQ2OTNhYjNmYjg3NWQ1YjQifQ%3D%3D; expires=Mon, 16-Sep-2019 22:03:39 GMT; Max-Age=7200; path=/; httponly, laravel_session=eyJpdiI6IktaRm1abHNGRkFoTWxxaUMxdmdnaHc9PSIsInZhbHVlIjoiYU1kTklFa280cUhIQnp5XC96NEpTMjF0aVpJcm5PMUN1UEVcL3BGRnlieUptVDNuNkgrcnBWUkJXREpyajk5dXkrIiwibWFjIjoiNTBjNGE3NWQ0YTI4MzZlYjA2YjE5MGJlZjJhZDg0YjBmZmU2MzExNDA1ZWJiNzk5OWUzY2E2NmQ3YzJhZWR
# ...

# %%
src = result.content
print(src)
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\n\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n                new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-KX76S82\');</script>\n\n<title>Climb White Rastafarian, Joshua Tree National Park</title>\n\n<meta http-equiv="Content-Language" content="en_US" />\n\n<link href="/css/ap-vendor-full.css?id=cd37e831c90909361542" rel="stylesheet" />\n\n\n<link rel="stylesheet" href="/css/styles-shared-all.css?id=c79e43280f24529957ee"/>\n\n\n<link rel="stylesheet" href="/css/styles-site
# ...

# %%
soup = BeautifulSoup(src, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-KX76S82');
#   </script>
#   <title>
#    Climb White Rastafarian, Joshua Tree National Park
#   </title>
#   <meta content="en_US" http-equiv="Content-Language">
#    <link href="/css/ap-vendor-full.css?id=cd37e831c90909361542" rel="stylesheet"/>
#    <link href="/css/styles-shared-all.css?id=c79e43280f24529957ee" rel="stylesheet"/>
# ...

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#              j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#              'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#          })(window,document,'script','dataLayer','GTM-KX76S82');</script>
#  <title>Climb White Rastafarian, Joshua Tree National Park</title>
#  <meta content="en_US" http-equiv="Content-Language">
#  <link href="/css/ap-vendor-full.css?id=cd37e831c90909361542" rel="stylesheet"/>
#  <link href="/css/styles-shared-all.css?id=c79e43280f24529957ee" rel="stylesheet"/>
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[2]

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#              j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#              'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#          })(window,document,'script','dataLayer','GTM-KX76S82');</script>
#  <title>Climb White Rastafarian, Joshua Tree National Park</title>
#  <meta content="en_US" http-equiv="Content-Language">
#  <link href="/css/ap-vendor-full.css?id=cd37e831c90909361542" rel="stylesheet"/>
#  <link href="/css/styles-shared-all.css?id=c79e43280f24529957ee" rel="stylesheet"/>
#  <link href="/css/styles-site-climb.css?id=ef0cd2be259f6fcfa7cc" rel="stylesheet"/>
# ...

# %%
body = list(html.children)[3]

# %%
list(body.children)
# Out:
# ['\n',
#  <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KX76S82" style="display:none;visibility:hidden" width="0"></iframe></noscript>,
#  '\n',
#  <div aria-hidden="true" class="modal fade login-modal" id="login-modal" role="dialog" tabindex="-1">
#  <div class="modal-dialog modal-sm" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span aria-hidden="true">
#  <img src="https://cdn.apstatic.com/img/icons/closeX-lightBg.svg"/>
#  </span>
#  </button>
#  <h2 class="modal-title">Sign Up or Log In</h2>
#  </div>
#  <div class="modal-body">
#  <div class="container-fluid">
#  <div class="text-xs-center">
#  <p class="text-muted"><a href="https://www.adventureprojects.net" target="_blank">Your login works with all Adventure Projects sites <img src="https://cdn.apstatic.com/img/arrows/nextGray.svg"/></a></p>
#  </div>
# ...

# %%
p = list(body.children)[1]

# %%
p.get_text()
# Out:
# ''

# %%
from bs4 import BeautifulSoup
import requests
url="https://www.mountainproject.com/route/105722593/white-rastafarian"
html=requests.get(url).text
soup=BeautifulSoup(html,'html.parser')

# To get the route description:
desc = soup.findAll("div",{"class":"fr-view"})
desc1 = soup.find(class_="fr-view").text
# Out:
# [<div class="fr-view">This problem is located on a large boulder at the Southeast end of Rock Hudson. Climb a juggy crack on an overhanging arete until it dies out 15 ft. up. Lean out left, onto the overhanging face, to a large flake. Finishes with an easy mantel 25 ft. off the deck. One of JTree's finest problems.</div>,
#  <div class="fr-view">Chalkbag and shoes!</div>]

# %%
desc = soup.find(class_="fr-view").text

# %%
desc
# Out:
# "This problem is located on a large boulder at the Southeast end of Rock Hudson. Climb a juggy crack on an overhanging arete until it dies out 15 ft. up. Lean out left, onto the overhanging face, to a large flake. Finishes with an easy mantel 25 ft. off the deck. One of JTree's finest problems."
